# %%
import pandas as pd
import numpy as np
import csv 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import wilcoxon

#https://altair-viz.github.io/gallery/errorbars_with_std.html
#import altair as alt
#from vega_datasets import data

#defining paths
results_post = 'Milestones - Post Experiment All.csv'
results_pre = 'Milestones - Pre Experiment.csv'
results_milestones = 'Milestones - timeStandard-prod-fill-nan-27032023.csv'

dataBinary_post = pd.read_csv(results_post)
dataPre = pd.read_csv(results_pre)
dataMilestones = pd.read_csv(results_milestones)

# %%
dataBinary_post
# Out:
#                     Participant      group  issue  \
# 0   FelipeFelixSantos@gmail.com  Treatment   5485
# 1                 gk325@nau.edu  Treatment   4612
# 2                sb3292@nau.edu  Treatment   5194
# 3         gummadisk99@gmail.com    Control   4612
# 4                 hk486@nau.edu  Treatment   5069
# 5                 kv582@nau.edu    Control   5485
# 6                 vg588@nau.edu  Treatment   5485
# 7                ma3932@nau.edu  Treatment   5485
# 8                 nk545@nau,edu    Control   5069
# 9                sm4332@nau.edu    Control   4612
# 10               jk2396@nau.edu  Treatment   5069
# 11               rm2878@nau.edu  Treatment   5679
# 12               st2364@nau.edu    Control   5485
# 13               klp468@nau.edu    Control   5069
#
#                        Why did you choose that issue?  \
# 0             Because of the "good first issue label"
# 1   I just thought it would be something related t...
# 2   I found that it was one of the concerns that I...
# 3   AS I SAID EARLIER, URL SHOULD BE VISIBLE TO TH...
# 4              That issue looked the most easy issue.
# 5   I chose this issue since its quite prevalent t...
# 6   because I have dealt with these kinds of param...
# 7   After looking at the description it appears to...
# 8                  search pattern and thought simmple
# 9   It is the only known issue to me that contains...
# 10  This is an issue related to GUI and logic rela...
# 11  Autosave is a useful features which allows the...
# 12  I want to fix this issue and excited to fix th...
# 13  I found it interesting and have some knowledge...
#
#    Summary: Why Did you choose  \
# 0           Useful information
# 1               Skills Matched
# 2                         Easy
# 3     Had idea of the solution
# 4                         Easy
# 5        Interested in problem
# 6               Skills Matched
# 7           Useful information
# 8                         Easy
# 9               Skills Matched
# 10              Skills Matched
# 11       Interested in problem
# 12       Interested in problem
# 13       Interested in problem
#
#                                   Post: Skills Needed     Skills Correct  \
# 0                                                None               None
# 1                                                None               None
# 2              Testing,Google Common,Input and Output  Google Common, IO
# 3                         User Interface (UI),Testing                 UI
# 4        User Interface (UI),Testing,Input and Output                 UI
# 5                                       Google Common      Google Common
# 6                                     Logging,Testing               None
# 7                User Interface (UI),Input and Output               None
# 8   User Interface (UI),Logging,Testing,Input and ...        Logging, UI
# 9        User Interface (UI),Testing,Input and Output             UI, IO
# 10  User Interface (UI),Logging,Testing,Input and ...        Logging, UI
# 11  Logging,Testing,Network Development,Google Com...            Logging
# 12                                   Input and Output               None
# 13                           Testing,Input and Output               None
#
#     Percentage Skills Correct            Post: Difficulty  DifficultyNumeric  \
# 0                    0.000000              Extremely easy                  1
# 1                    0.000000          Somewhat difficult                  4
# 2                    0.666667          Somewhat difficult                  4
# 3                    0.333333          Somewhat difficult                  4
# 4                    0.200000  Neither easy nor difficult                  3
# 5                    0.250000               Somewhat easy                  2
# 6                    0.000000               Somewhat easy                  2
# 7                    0.000000          Somewhat difficult                  4
# 8                    0.400000          Somewhat difficult                  4
# 9                    0.666667         Extremely difficult                  5
# 10                   0.400000          Somewhat difficult                  4
# 11                   0.333333          Somewhat difficult                  4
# 12                   0.000000          Somewhat difficult                  4
# 13                   0.000000  Neither easy nor difficult                  4
#
#     ...                               Post: Helpful Labels  \
# 0   ...                                   good first issue
# 1   ...                                             search
# 2   ...  API: Google Common,API: Logging,type: bug,exte...
# 3   ...          API: User Interface,preferences,type: bug
# 4   ...         API: User Interface,entry editor,type: bug
# 5   ...                API: Test,API: Google Common,search
# 6   ...     API: Input and Output,fetcher,good first issue
# 7   ...                              API: Input and Output
# 8   ...                                   search,type: bug
# 9   ...                      search,entry editor,type: bug
# 10  ...                      API: User Interface,type: bug
# 11  ...                    API: Test,API: Input and Output
# 12  ...                              API: Input and Output
# 13  ...                                             search
#
#             Post: Confidence Level Had Skills ConfidenceNumeric  \
# 0                                   Confident                 4
# 1                                     Average                 3
# 2                                     Average                 3
# 3   Not confident (can manage, but difficult)                 2
# 4   Not confident (can manage, but difficult)                 2
# 5                                     Average                 3
# 6                                   Confident                 4
# 7                                     Average                 3
# 8                                     Average                 3
# 9   Not confident (can manage, but difficult)                 2
# 10  Not confident (can manage, but difficult)                 2
# 11  Not confident (can manage, but difficult)                 2
# 12                                    Average                 3
# 13                                    Average                 3
#
#                             Post: Additional Feedback Post: Education Level  \
# 0   1 - Not being able to use shortcuts due to the...  Undergraduate degree
# 1                                 had fun. Thank you.       Master's degree
# 2        I had a lot of fun trying to debug the code.       Master's degree
# 3                                                 NaN  Undergraduate degree
# 4                                                 NaN           High school
# 5                                                 NaN  Undergraduate degree
# 6                                                 NaN  Undergraduate degree
# 7                                                 NaN  Undergraduate degree
# 8                                                 NaN  Undergraduate degree
# 9                                                 NaN  Undergraduate degree
# 10                                                NaN  Undergraduate degree
# 11                                                NaN  Undergraduate degree
# 12                                                NaN  Undergraduate degree
# 13                                                NaN  Undergraduate degree
#
#                  Occupation Gender Country of Origin  \
# 0    Professional Developer    Man            Brazil
# 1        Student - Graduate    Man             India
# 2        Student - Graduate  Woman             India
# 3        Student - Graduate    Man             India
# 4   Student - Undergraduate    Man       South Korea
# 5        Student - Graduate  Woman             India
# 6        Student - Graduate    Man             India
# 7        Student - Graduate    Man             India
# 8        Student - Graduate    Man             India
# 9        Student - Graduate  Woman             India
# 10       Student - Graduate    Man             India
# 11       Student - Graduate    Man             India
# 12       Student - Graduate    Man             India
# 13       Student - Graduate  Woman             India
#
#                 Curr Country         Age
# 0                   Portugal    25 to 34
# 1   United States of America    25 to 34
# 2   United States of America  24 or less
# 3   United States of America  24 or less
# 4   United States of America  24 or less
# 5   United States of America    25 to 34
# 6   United States of America  24 or less
# 7   United States of America    25 to 34
# 8   United States of America  24 or less
# 9   United States of America    25 to 34
# 10  United States of America  24 or less
# 11  United States of America  24 or less
# 12  United States of America  24 or less
# 13  United States of America  24 or less
#
# [14 rows x 27 columns]

# %%
dataBinary_post.drop(columns=["Why did you choose that issue?", "Post: Explain Difficulty", "Post: Explain Accomplishment", "Post: How could we make it easier?", "Post: Additional Feedback"])
# Out:
#                     Participant      group  issue Summary: Why Did you choose  \
# 0   FelipeFelixSantos@gmail.com  Treatment   5485          Useful information
# 1                 gk325@nau.edu  Treatment   4612              Skills Matched
# 2                sb3292@nau.edu  Treatment   5194                        Easy
# 3         gummadisk99@gmail.com    Control   4612    Had idea of the solution
# 4                 hk486@nau.edu  Treatment   5069                        Easy
# 5                 kv582@nau.edu    Control   5485       Interested in problem
# 6                 vg588@nau.edu  Treatment   5485              Skills Matched
# 7                ma3932@nau.edu  Treatment   5485          Useful information
# 8                 nk545@nau,edu    Control   5069                        Easy
# 9                sm4332@nau.edu    Control   4612              Skills Matched
# 10               jk2396@nau.edu  Treatment   5069              Skills Matched
# 11               rm2878@nau.edu  Treatment   5679       Interested in problem
# 12               st2364@nau.edu    Control   5485       Interested in problem
# 13               klp468@nau.edu    Control   5069       Interested in problem
#
#                                   Post: Skills Needed     Skills Correct  \
# 0                                                None               None
# 1                                                None               None
# 2              Testing,Google Common,Input and Output  Google Common, IO
# 3                         User Interface (UI),Testing                 UI
# 4        User Interface (UI),Testing,Input and Output                 UI
# 5                                       Google Common      Google Common
# 6                                     Logging,Testing               None
# 7                User Interface (UI),Input and Output               None
# 8   User Interface (UI),Logging,Testing,Input and ...        Logging, UI
# 9        User Interface (UI),Testing,Input and Output             UI, IO
# 10  User Interface (UI),Logging,Testing,Input and ...        Logging, UI
# 11  Logging,Testing,Network Development,Google Com...            Logging
# 12                                   Input and Output               None
# 13                           Testing,Input and Output               None
#
#     Percentage Skills Correct            Post: Difficulty  DifficultyNumeric  \
# 0                    0.000000              Extremely easy                  1
# 1                    0.000000          Somewhat difficult                  4
# 2                    0.666667          Somewhat difficult                  4
# 3                    0.333333          Somewhat difficult                  4
# 4                    0.200000  Neither easy nor difficult                  3
# 5                    0.250000               Somewhat easy                  2
# 6                    0.000000               Somewhat easy                  2
# 7                    0.000000          Somewhat difficult                  4
# 8                    0.400000          Somewhat difficult                  4
# 9                    0.666667         Extremely difficult                  5
# 10                   0.400000          Somewhat difficult                  4
# 11                   0.333333          Somewhat difficult                  4
# 12                   0.000000          Somewhat difficult                  4
# 13                   0.000000  Neither easy nor difficult                  4
#
#                 Summary: Explain Difficulty  ...  \
# 0                             Simple change  ...
# 1           Lack of familiarity with JabRef  ...
# 2           Lack of familiarity with JabRef  ...
# 3           Lack of familiarity with JabRef  ...
# 4   Unsure of exact solution implementation  ...
# 5                         Rating out of ten  ...
# 6            Issue had relevant information  ...
# 7           Lack of familiarity with JabRef  ...
# 8                         Rating out of ten  ...
# 9           Lack of familiarity with JabRef  ...
# 10  Unsure of exact solution implementation  ...
# 11          Lack of familiarity with JabRef  ...
# 12          Lack of familiarity with JabRef  ...
# 13                        Rating out of ten  ...
#
#       Summary: How could we make it easier?  \
# 0   Additional documentation and issue info
# 1   Additional documentation and issue info
# 2    Improved comments and code readability
# 3                                      None
# 4   Additional documentation and issue info
# 5                                      None
# 6                   Improve logging in code
# 7   Additional documentation and issue info
# 8    Improved comments and code readability
# 9                                      None
# 10   Improved comments and code readability
# 11   Improved comments and code readability
# 12  Additional documentation and issue info
# 13  Improve experiement system/environment
#
#                                  Post: Helpful Labels  \
# 0                                    good first issue
# 1                                              search
# 2   API: Google Common,API: Logging,type: bug,exte...
# 3           API: User Interface,preferences,type: bug
# 4          API: User Interface,entry editor,type: bug
# 5                 API: Test,API: Google Common,search
# 6      API: Input and Output,fetcher,good first issue
# 7                               API: Input and Output
# 8                                    search,type: bug
# 9                       search,entry editor,type: bug
# 10                      API: User Interface,type: bug
# 11                    API: Test,API: Input and Output
# 12                              API: Input and Output
# 13                                             search
#
#             Post: Confidence Level Had Skills ConfidenceNumeric  \
# 0                                   Confident                 4
# 1                                     Average                 3
# 2                                     Average                 3
# 3   Not confident (can manage, but difficult)                 2
# 4   Not confident (can manage, but difficult)                 2
# 5                                     Average                 3
# 6                                   Confident                 4
# 7                                     Average                 3
# 8                                     Average                 3
# 9   Not confident (can manage, but difficult)                 2
# 10  Not confident (can manage, but difficult)                 2
# 11  Not confident (can manage, but difficult)                 2
# 12                                    Average                 3
# 13                                    Average                 3
#
#    Post: Education Level               Occupation Gender Country of Origin  \
# 0   Undergraduate degree   Professional Developer    Man            Brazil
# 1        Master's degree       Student - Graduate    Man             India
# 2        Master's degree       Student - Graduate  Woman             India
# 3   Undergraduate degree       Student - Graduate    Man             India
# 4            High school  Student - Undergraduate    Man       South Korea
# 5   Undergraduate degree       Student - Graduate  Woman             India
# 6   Undergraduate degree       Student - Graduate    Man             India
# 7   Undergraduate degree       Student - Graduate    Man             India
# 8   Undergraduate degree       Student - Graduate    Man             India
# 9   Undergraduate degree       Student - Graduate  Woman             India
# 10  Undergraduate degree       Student - Graduate    Man             India
# 11  Undergraduate degree       Student - Graduate    Man             India
# 12  Undergraduate degree       Student - Graduate    Man             India
# 13  Undergraduate degree       Student - Graduate  Woman             India
#
#                 Curr Country         Age
# 0                   Portugal    25 to 34
# 1   United States of America    25 to 34
# 2   United States of America  24 or less
# 3   United States of America  24 or less
# 4   United States of America  24 or less
# 5   United States of America    25 to 34
# 6   United States of America  24 or less
# 7   United States of America    25 to 34
# 8   United States of America  24 or less
# 9   United States of America    25 to 34
# 10  United States of America  24 or less
# 11  United States of America  24 or less
# 12  United States of America  24 or less
# 13  United States of America  24 or less
#
# [14 rows x 22 columns]

# %%
#Relevel the factors for Difficulty
#TODO Wilson-Cox test for numeric values and difference between groups. 
#TODO Test for the factors/string based scales. 
#dataBinary_post = dataBinary_post.assign(Difficulty = [1 if a == "Extremely easy" 2 elif a == "Somewhat Easy" else  for a in dataBinary_post['Post: Difficulty']])
#dataBinary_post.head()
#dataBinary_post["Post: Difficulty"] = pd.Categorical(dataBinary_post["Post: Difficulty"])
#1 is low confidence, 5 is high confidence
#dataBinary_post["Post: Difficulty"] = dataBinary_post["Post: Difficulty"].cat.codes
postMeans = dataBinary_post.groupby(['group']).mean()
postMeans
# Out:
#                  issue  Percentage Skills Correct  DifficultyNumeric  \
# group
# Control    5055.333333                      0.275           3.833333
# Treatment  5259.750000                      0.200           3.250000
#
#            ConfidenceNumeric
# group
# Control             2.666667
# Treatment           2.875000

# %%
confidenceCounts = dataBinary_post.groupby(['group', 'Post: Confidence Level Had Skills'])['Participant'].count()
confidenceCounts
# Out:
# group      Post: Confidence Level Had Skills
# Control    Average                                      4
#            Not confident (can manage, but difficult)    2
# Treatment  Average                                      3
#            Confident                                    2
#            Not confident (can manage, but difficult)    3
# Name: Participant, dtype: int64

# %% [markdown]
# #Relevel the factors for Difficulty
# #TODO Wilson-Cox test for numeric values and difference between groups.
# #TODO Test for the factors/string based scales.
# #dataBinary_post = dataBinary_post.assign(Difficulty = [1 if a == "Extremely easy" 2 elif a == "Somewhat Easy" else  for a in dataBinary_post['Post: Difficulty']])
# #dataBinary_post.head()
# #dataBinary_post["Post: Difficulty"] = pd.Categorical(dataBinary_post["Post: Difficulty"])
# #1 is low confidence, 5 is high confidence
# #dataBinary_post["Post: Difficulty"] = dataBinary_post["Post: Difficulty"].cat.codes
# postMeans = dataBinary_post.groupby(['group', ']).mean()
# postMeans

# %%
control = dataBinary_post[dataBinary_post["group"]=='Control']
treatment = dataBinary_post[dataBinary_post["group"]=='Treatment']
len(control)
len(treatment)
#wilcoxon(control, treatment)
# Out:
# 8

# %%
postMeans["DifficultyNumeric"].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='group'>

# %%
dataPre.head()
# Out:
#              Participant      group  issue_number  \
# 0  gummadisk99@gmail.com    Control          4612
# 1          hk486@nau.edu  Treatment          5069
# 2         ap3535@nau.edu    Control          5485
# 3          kv582@nau.edu    Control          5485
# 4          vg588@nau.edu  Treatment          5485
#
#                              Pre:Why did they select  \
# 0  url should be visible to the end users and sho...
# 1          This issue looked the easy to contribute.
# 2  The issue was descriptive compared to other is...
# 3  I chose this issue since its an issue widely f...
# 4  This feel like newer version of the package ha...
#
#        Pre: Summary: Why did you select  \
# 0             Had idea of the solution.
# 1                                  Easy
# 2  Issue more descriptive than others.
# 3                Interested in problem.
# 4              Had idea of the solution
#
#                        Pre: Confidence Level  \
# 0  Not confident (can manage, but difficult)
# 1  Not confident (can manage, but difficult)
# 2                                  Confident
# 3                                    Average
# 4                                    Average
#
#                        Pre: Explain Confidence Level  \
# 0                                                  2
# 1  I am not sure if I can change the issue. But I...
# 2       I have prior experience of working with API.
# 3  I have initially started my research on deprec...
# 4  I have handled the package dependencies upgrad...
#
#            Pre: Summary: Explain Confidence Level  \
# 0                               Rating out of ten
# 1  Idea of the solution and location of problem.
# 2                  Prior Experience/Skills Match.
# 3                  Prior Experience/Skills Match.
# 4                  Prior Experience/Skills Match.
#
#                                   Pre: Skills Needed Pre: Skills Correct  \
# 0                        User Interface (UI),Testing                  UI
# 1  User Interface (UI),Testing,Network Developmen...         UI, Network
# 2                     Google Common,Input and Output                Util
# 3                              Testing,Google Common                Util
# 4                   Logging,Testing,Input and Output                None
#
#    Pre: Percentage Skills Correct  \
# 0                            0.50
# 1                            0.40
# 2                            0.25
# 3                            0.25
# 4                            0.00
#
#                               Pre: Helpful Labels  \
# 0              preferences,entry editor,type: bug
# 1                             API: User Interface
# 2                               None of the above
# 3             API: Test,API: Google Common,search
# 4  API: Input and Output,fetcher,good first issue
#
#                             Post: Skills Needed
# 0                   User Interface (UI),Testing
# 1  User Interface (UI),Testing,Input and Output
# 2                                 Google Common
# 3                                 Google Common
# 4                               Logging,Testing

# %%
preMeans = dataPre.groupby(['group']).mean()
preMeans
# Out:
#            issue_number  Pre: Percentage Skills Correct
# group
# Control     5116.714286                        0.219048
# Treatment   5357.400000                        0.226667

# %%
dataPre.head()
# Out:
#              Participant      group  issue_number  \
# 0  gummadisk99@gmail.com    Control          4612
# 1          hk486@nau.edu  Treatment          5069
# 2         ap3535@nau.edu    Control          5485
# 3          kv582@nau.edu    Control          5485
# 4          vg588@nau.edu  Treatment          5485
#
#                              Pre:Why did they select  \
# 0  url should be visible to the end users and sho...
# 1          This issue looked the easy to contribute.
# 2  The issue was descriptive compared to other is...
# 3  I chose this issue since its an issue widely f...
# 4  This feel like newer version of the package ha...
#
#        Pre: Summary: Why did you select  \
# 0             Had idea of the solution.
# 1                                  Easy
# 2  Issue more descriptive than others.
# 3                Interested in problem.
# 4              Had idea of the solution
#
#                        Pre: Confidence Level  \
# 0  Not confident (can manage, but difficult)
# 1  Not confident (can manage, but difficult)
# 2                                  Confident
# 3                                    Average
# 4                                    Average
#
#                        Pre: Explain Confidence Level  \
# 0                                                  2
# 1  I am not sure if I can change the issue. But I...
# 2       I have prior experience of working with API.
# 3  I have initially started my research on deprec...
# 4  I have handled the package dependencies upgrad...
#
#            Pre: Summary: Explain Confidence Level  \
# 0                               Rating out of ten
# 1  Idea of the solution and location of problem.
# 2                  Prior Experience/Skills Match.
# 3                  Prior Experience/Skills Match.
# 4                  Prior Experience/Skills Match.
#
#                                   Pre: Skills Needed Pre: Skills Correct  \
# 0                        User Interface (UI),Testing                  UI
# 1  User Interface (UI),Testing,Network Developmen...         UI, Network
# 2                     Google Common,Input and Output                Util
# 3                              Testing,Google Common                Util
# 4                   Logging,Testing,Input and Output                None
#
#    Pre: Percentage Skills Correct  \
# 0                            0.50
# 1                            0.40
# 2                            0.25
# 3                            0.25
# 4                            0.00
#
#                               Pre: Helpful Labels  \
# 0              preferences,entry editor,type: bug
# 1                             API: User Interface
# 2                               None of the above
# 3             API: Test,API: Google Common,search
# 4  API: Input and Output,fetcher,good first issue
#
#                             Post: Skills Needed
# 0                   User Interface (UI),Testing
# 1  User Interface (UI),Testing,Input and Output
# 2                                 Google Common
# 3                                 Google Common
# 4                               Logging,Testing

# %%
dataBinary_post.head()
# Out:
#                    Participant      group  issue  \
# 0  FelipeFelixSantos@gmail.com  Treatment   5485
# 1                gk325@nau.edu  Treatment   4612
# 2               sb3292@nau.edu  Treatment   5194
# 3        gummadisk99@gmail.com    Control   4612
# 4                hk486@nau.edu  Treatment   5069
#
#                       Why did you choose that issue?  \
# 0            Because of the "good first issue label"
# 1  I just thought it would be something related t...
# 2  I found that it was one of the concerns that I...
# 3  AS I SAID EARLIER, URL SHOULD BE VISIBLE TO TH...
# 4             That issue looked the most easy issue.
#
#   Summary: Why Did you choose                           Post: Skills Needed  \
# 0          Useful information                                          None
# 1              Skills Matched                                          None
# 2                        Easy        Testing,Google Common,Input and Output
# 3    Had idea of the solution                   User Interface (UI),Testing
# 4                        Easy  User Interface (UI),Testing,Input and Output
#
#       Skills Correct  Percentage Skills Correct            Post: Difficulty  \
# 0               None                   0.000000              Extremely easy
# 1               None                   0.000000          Somewhat difficult
# 2  Google Common, IO                   0.666667          Somewhat difficult
# 3                 UI                   0.333333          Somewhat difficult
# 4                 UI                   0.200000  Neither easy nor difficult
#
#    DifficultyNumeric  ...                               Post: Helpful Labels  \
# 0                  1  ...                                   good first issue
# 1                  4  ...                                             search
# 2                  4  ...  API: Google Common,API: Logging,type: bug,exte...
# 3                  4  ...          API: User Interface,preferences,type: bug
# 4                  3  ...         API: User Interface,entry editor,type: bug
#
#            Post: Confidence Level Had Skills ConfidenceNumeric  \
# 0                                  Confident                 4
# 1                                    Average                 3
# 2                                    Average                 3
# 3  Not confident (can manage, but difficult)                 2
# 4  Not confident (can manage, but difficult)                 2
#
#                            Post: Additional Feedback Post: Education Level  \
# 0  1 - Not being able to use shortcuts due to the...  Undergraduate degree
# 1                                had fun. Thank you.       Master's degree
# 2       I had a lot of fun trying to debug the code.       Master's degree
# 3                                                NaN  Undergraduate degree
# 4                                                NaN           High school
#
#                 Occupation Gender Country of Origin              Curr Country  \
# 0   Professional Developer    Man            Brazil                  Portugal
# 1       Student - Graduate    Man             India  United States of America
# 2       Student - Graduate  Woman             India  United States of America
# 3       Student - Graduate    Man             India  United States of America
# 4  Student - Undergraduate    Man       South Korea  United States of America
#
#           Age
# 0    25 to 34
# 1    25 to 34
# 2  24 or less
# 3  24 or less
# 4  24 or less
#
# [5 rows x 27 columns]

# %%
summaryPreChoosing = dataPre.groupby(['Pre: Summary: Why did you select'])['Participant'].count()
summaryPreChoosing
# Out:
# Pre: Summary: Why did you select
# Easy                                                      1
# Easy. Had idea of the solution.                           1
# Had idea of the solution                                  1
# Had idea of the solution.                                 1
# Idea of solution                                          1
# Interested in problem.                                    2
# Interested in problem.                                    1
# Issue more descriptive than others.                       1
# None.                                                     1
# Skills matched. Issue descriptive.                        1
# Skills matched. Prior experience with similar problem.    1
# Name: Participant, dtype: int64

# %%
summaryConfidenceLevel = dataPre.groupby(['Pre: Summary: Explain Confidence Level', 'group'])['Participant'].count()
summaryConfidenceLevel
# Out:
# Pre: Summary: Explain Confidence Level          group
# Idea of the solution and location of problem.   Control      1
#                                                 Treatment    3
# Prior Experience/Skills Match.                  Control      2
#                                                 Treatment    2
# Rating out of ten                               Control      4
# Name: Participant, dtype: int64

# %%
summaryWhyChoose = dataBinary_post.groupby(['Summary: Why Did you choose', 'group'])['Participant'].count()
summaryWhyChoose
# Out:
# Summary: Why Did you choose  group
# Easy                         Control      1
#                              Treatment    2
# Had idea of the solution     Control      1
# Interested in problem        Control      3
#                              Treatment    1
# Skills Matched               Control      1
#                              Treatment    3
# Useful information           Treatment    2
# Name: Participant, dtype: int64

# %%
feedbackSummaryDifficulty = dataBinary_post.groupby(['Summary: Explain Difficulty', 'group'])['Participant'].count()
feedbackSummaryDifficulty
# Out:
# Summary: Explain Difficulty              group
# Issue had relevant information           Treatment    1
# Lack of familiarity with JabRef          Control      3
#                                          Treatment    4
# Rating out of ten                        Control      3
# Simple change                            Treatment    1
# Unsure of exact solution implementation  Treatment    2
# Name: Participant, dtype: int64

# %%
summaryAccomplishment = dataBinary_post.groupby(["Summary: Explain Accomplishment", "group"])['Participant'].count()
summaryAccomplishment
# Out:
# Summary: Explain Accomplishment                          group
# Couldn't find location                                   Control      1
# Couldn't find location                                   Treatment    1
# Couldn't implement code                                  Control      4
#                                                          Treatment    2
# Couldn't understand the problem and high level solution  Treatment    1
# Found code location                                      Treatment    1
# Unable to verify solution                                Control      1
#                                                          Treatment    3
# Name: Participant, dtype: int64

# %%
summaryMakeEasier = dataBinary_post.groupby(["Summary: How could we make it easier?", "group"])['Participant'].count()
summaryMakeEasier
# Out:
# Summary: How could we make it easier?    group
# Additional documentation and issue info  Control      1
#                                          Treatment    4
# Improve experiement system/environment   Control      1
# Improve logging in code                  Treatment    1
# Improved comments and code readability   Control      1
#                                          Treatment    3
# None                                     Control      3
# Name: Participant, dtype: int64

# %%
dataMilestones.head()
# Out:
#                    Participant       start  issue  problem  folder  file  \
# 0                  ItaloSantos     2:35 PM     17       17      18    18
# 1  FelipeFelixSantos@gmail.com    10:15 AM      2        3      44    45
# 2                gk325@nau.edu  3:09:00 PM      1        6      56    56
# 3               sb3292@nau.edu  4:21:00 PM      3       19      23    23
# 4        gummadisk99@gmail.com     1:20 PM      4       14      38    38
#
#    class  method  line  solution  ...  alternative answer  \
# 0     19      21    21        24  ...                 NaN
# 1     45      46    47        48  ...                 NaN
# 2     58      60    60        60  ...                 NaN
# 3     23      27    27        46  ...                   y
# 4     38      41    41        50  ...                 NaN
#
#    Number of Milestones  Gift card requested  Gift card received      group  \
# 0                     3                    y                   y    Control
# 1                     7                    y                   y  Treatment
# 2                     0                    y                   y  Treatment
# 3                     1                    y                   y  Treatment
# 4                     0                    y                   y    Control
#
#    issue_number  Control YOE Control Contribs Alt YOE Alt Contrib
# 0          5679          4.0              0.0     NaN         NaN
# 1          5485          NaN              NaN     7.0         0.0
# 2          4612          3.0              0.0     NaN         NaN
# 3          5194          NaN              NaN     9.0         9.0
# 4          4612          1.0              1.0     NaN         NaN
#
# [5 rows x 35 columns]

# %%
from scipy.stats import mannwhitneyu
milestonesinfo = dataMilestones[['Number of Milestones', 'group']]
M_control = milestonesinfo[dataMilestones["group"] == 'Control']
print(M_control)
control_milestones = M_control['Number of Milestones'].astype('int32')
#print(control_milestones.dtype)

M_treatment = milestonesinfo[dataMilestones["group"] == 'Treatment']
treatment_milestones = M_treatment['Number of Milestones'].astype('int32')
print(treatment_milestones)

stat, p = mannwhitneyu(control_milestones, treatment_milestones)
print('Statistics=', stat, 'p=', p)
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
#     Number of Milestones    group
# 0                      3  Control
# 4                      0  Control
# 6                      0  Control
# 9                      1  Control
# 10                     0  Control
# 13                     0  Control
# 14                     1  Control
# 1     7
# 2     0
# 3     1
# 5     1
# 7     1
# 8     6
# 11    1
# 12    1
# Name: Number of Milestones, dtype: int32
# Statistics= 15.0 p= 0.11970096046232809
# Same distribution (fail to reject H0)

# %%
numMilestonesAvg = dataMilestones.groupby(['group'])["Number of Milestones"].mean()
numMilestonesAvg
# Out:
# group
# Control      0.714286
# Treatment    2.250000
# Name: Number of Milestones, dtype: float64

# %%
numMilestonesMedian = dataMilestones.groupby(['group'])["Number of Milestones"].median()
numMilestonesMedian
#numMilestonesAvg.plot(kind='bar')
# Out:
# group
# Control      0.0
# Treatment    1.0
# Name: Number of Milestones, dtype: float64
